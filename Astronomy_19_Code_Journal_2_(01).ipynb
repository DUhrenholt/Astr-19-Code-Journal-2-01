# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,1,100)

def b(x):
    return np.exp(x)

# %%
y = np.exp(x)

f = plt.figure(figsize=(7,7))
plt.errorbar(x,y,0,fmt='o')
plt.xlabel('Time [milliseconds]')
plt.ylabel('Awesomeness')

plt.savefig('Awesomeness_vs_Time.pdf')
